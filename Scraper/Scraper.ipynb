# %%
#import function to copy the scraper folder into the dist-packages or site-packages libraries
from copy_scraper import copy_scraper
copy_scraper()
# Out:
# Package will be placed in: C:\Users\jitse\anaconda3\lib\site-packages, is this the correct package directory? [Y/n] n
# Specify path or abortabort

# %%
####
# 1. Initialise
####
# Load Packages
from funda_scraper import FundaScraper
import pandas as pd

# %%
####
# 2. Data
####
# Obtain Data
scraper = FundaScraper(area="provincie-noord-holland", want_to="buy", find_past=False, n_pages = 100)
df = scraper.run()
# Out:
# 2023-03-21 20:15:42,158 - INFO - *** Phase 1: Fetch all the available links from all pages ***  (scrape.py:107)
# 100%|████████████████████████████████████████████████████████████████████████████████| 101/101 [00:42<00:00,  2.39it/s]
# 2023-03-21 20:16:24,351 - INFO - *** Got all the urls. 1500 houses found in 100 pages. *** (scrape.py:118)
# 2023-03-21 20:16:24,355 - INFO - *** Phase 2: Start scraping results from individual links *** (scrape.py:186)
# C:\Users\jitse\anaconda3\lib\site-packages\funda_scraper\scrape.py:191: TqdmWarning: Iterable length 1500 > 1000 but `chunksize` is not set. This may seriously degrade multiprocess performance. Set `chunksize=1` or more.
#   content = process_map(self.scrape_from_url, self.links, max_workers=pools)
#   0%|          | 0/1500 [00:00<?, ?it/s]
# 2023-03-21 20:27:55,817 - INFO - *** All scraping done: 1500 results *** (scrape.py:198)
# 2023-03-21 20:27:55,821 - INFO - *** Cleaning data *** (scrape.py:232)
# ...

# %%
####
# 3. Store
####
# Store Data
df.to_csv('data/funda_buy_21-03-2023(sample100p).csv')

# %%
####
# 4. Explore Data
####
# Explore
df.head()
# Out:
#    house_id                     city   house_type    building_type   price  \
# 0  42003551  provincie-noord-holland         huis  Resale property  375000
# 1  42084829  provincie-noord-holland         huis  Resale property  400000
# 2  42855712  provincie-noord-holland         huis  Resale property  469000
# 3  42003288  provincie-noord-holland  appartement  Resale property  285000
# 4  42062489  provincie-noord-holland         huis  Resale property  595000
#
#    price_m2  room  bedroom  bathroom  living_area  ... has_balcony  \
# 0    2840.9     5        4         1          132  ...           0
# 1    4301.1     4        3         1           93  ...           0
# 2    3908.3     4        3         2          120  ...           0
# 3    6333.3     2        1         1           45  ...           1
# 4    5085.5     4        3         0          117  ...           0
#
#    has_garden   zip               address year_built  house_age  \
# ...
